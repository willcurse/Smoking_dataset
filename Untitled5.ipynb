# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# # 1: Data Collection

# %% [markdown]
# # 1.1 Data Loading

# %%
data=pd.read_csv(r'C:\Users\Administrator\Desktop\DA-jupyter\smoke_data.csv')
data
# Out:
#       Year Age_Group  Gender  Smoking_Prevalence  Drug_Experimentation  \
# 0     2024     15-19    Both               18.85                 32.40
# 1     2024     10-14  Female               34.88                 41.57
# 2     2023     10-14    Both               42.00                 56.80
# 3     2024     40-49    Both               33.75                 42.90
# 4     2023     15-19    Male               47.90                 39.62
# ...    ...       ...     ...                 ...                   ...
# 9995  2023     15-19    Male               49.17                 10.21
# 9996  2020       80+  Female               48.00                 30.85
# 9997  2021     25-29    Both               47.62                 39.54
# 9998  2022     40-49    Male                9.37                 11.64
# 9999  2023     10-14    Male               43.77                 21.95
#
#      Socioeconomic_Status  Peer_Influence School_Programs  Family_Background  \
# ...

# %% [markdown]
# # 1.2 Null Data Checking

# %%
data.isnull().sum()
# Out:
# Year                    0
# Age_Group               0
# Gender                  0
# Smoking_Prevalence      0
# Drug_Experimentation    0
# Socioeconomic_Status    0
# Peer_Influence          0
# School_Programs         0
# Family_Background       0
# Mental_Health           0
# Access_to_Counseling    0
# Parental_Supervision    0
# Substance_Education     0
# Community_Support       0
# Media_Influence         0
# dtype: int64

# %% [markdown]
# # 2: Data Cleaning

# %% [markdown]
# # 2.1 data information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  10000 non-null  int64
#  1   Age_Group             10000 non-null  object
#  2   Gender                10000 non-null  object
#  3   Smoking_Prevalence    10000 non-null  float64
#  4   Drug_Experimentation  10000 non-null  float64
#  5   Socioeconomic_Status  10000 non-null  object
#  6   Peer_Influence        10000 non-null  int64
#  7   School_Programs       10000 non-null  object
#  8   Family_Background     10000 non-null  int64
#  9   Mental_Health         10000 non-null  int64
#  10  Access_to_Counseling  10000 non-null  object
#  11  Parental_Supervision  10000 non-null  int64
#  12  Substance_Education   10000 non-null  object
#  13  Community_Support     10000 non-null  int64
#  14  Media_Influence       10000 non-null  int64
# ...

# %%
data.describe()
# Out:
#                Year  Smoking_Prevalence  Drug_Experimentation  Peer_Influence  \
# count  10000.000000        10000.000000          10000.000000    10000.000000
# mean    2022.000500           27.439257             40.150182        5.440100
# std        1.425027           12.975528             17.515917        2.863151
# min     2020.000000            5.000000             10.000000        1.000000
# 25%     2021.000000           16.160000             24.920000        3.000000
# 50%     2022.000000           27.355000             40.100000        5.000000
# 75%     2023.000000           38.672500             55.462500        8.000000
# max     2024.000000           50.000000             69.990000       10.000000
#
#        Family_Background  Mental_Health  Parental_Supervision  \
# count       10000.000000   10000.000000          10000.000000
# mean            5.513300       5.469800              5.528000
# std             2.865038       2.879326              2.891514
# ...

# %% [markdown]
# # 3: Data Analysis

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %% [markdown]
# # 3.1 Trend Analysis: How has smoking prevalence changed over the years for different age groups?

# %%
plt.figure(figsize=(10,6))
sns.lineplot(y='Smoking_Prevalence',x='Year',data=data,hue='Age_Group',marker='o')
plt.title('How has smoking prevalence changed over the years for different age groups')
plt.xlabel('Year')
plt.ylabel('Smoking_Prevalence')
plt.show()

# %% [markdown]
# # 3.2 Age vs. Smoking: Which age group shows the highest smoking prevalence across all years?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Age_Group',y='Smoking_Prevalence',data=data)
plt.title('Which age group shows the highest smoking prevalence across all years')
plt.xlabel('Age_Group')
plt.ylabel('Smoking_Prevalence')
plt.show()

# %% [markdown]
# # 3.3 Gender Differences: How does smoking prevalence vary between males and females within different age groups?

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Smoking_Prevalence',y='Gender',data=data)
plt.title('How does smoking prevalence vary between males and females within different age groups')
plt.xlabel('Smoking_Prevalence')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# # 3.4 Socioeconomic Status Impact: What is the relationship between socioeconomic status and smoking prevalence?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Socioeconomic_Status',y='Smoking_Prevalence',data=data)
plt.title(' What is the relationship between socioeconomic status and smoking prevalence?')
plt.xlabel('Socioeconomic_Status')
plt.ylabel('Smoking_Prevalence')
plt.show()

# %% [markdown]
# # 3.5 Peer Influence: Is there a correlation between peer influence scores and smoking prevalence?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
#calculate corelation
correlation=data['Peer_Influence'].corr(data['Smoking_Prevalence'])
correlation

plt.figure(figsize=(8,6))
sns.scatterplot(x='Peer_Influence', y='Smoking_Prevalence', data=data)
plt.title(f'Correlation between Peer Influence and Smoking Prevalence is: {correlation:.2f}')
plt.xlabel('Peer Influence Score')
plt.ylabel('Smoking Prevalence (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# # 3.6 Drug Experimentation: How does drug experimentation vary with different levels of smoking prevalence?

# %%
       data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Smoking_Prevalence', y='Drug_Experimentation', data=data)
plt.title('Drug Experimentation by School Programs')
plt.show()

# %% [markdown]
# # 3.7 School Programs Effectiveness: Do individuals who participated in school programs have lower smoking rates?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='School_Programs',y='Smoking_Prevalence',data=data)
plt.title('Drug Experimentation by School Programs')
plt.show()

# %% [markdown]
# # 3.8 Family Support Impact: What is the relationship between family background scores and smoking prevalence?

# %%
correlation=data['Family_Background'].corr(data['Smoking_Prevalence'])

plt.figure(figsize=(10,6))
sns.scatterplot(x='Family_Background',y='Smoking_Prevalence',data=data)
plt.title(f'the relationship between family background scores and smoking prevalence corr: {correlation }')
plt.show()

# %% [markdown]
# # 3.9 Mental Health: Does mental health score correlate with smoking prevalence or drug experimentation?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
corr1=data['Mental_Health'].corr(data['Smoking_Prevalence'])
corr2=data['Mental_Health'].corr(data['Drug_Experimentation'])

plt.figure(figsize=(10,6))
sns.scatterplot(x='Mental_Health',y='Smoking_Prevalence',data=data)
plt.title(f'mental health score correlate with smoking prevalence corr: {corr1}')
plt.show()

plt.figure(figsize=(10,6))
sns.scatterplot(x='Mental_Health',y='Drug_Experimentation',data=data)
plt.title(f'mental health score correlate with drug experimentation corr: {corr2 }')
plt.show()

# %% [markdown]
# # 3.10 Parental Supervision: What is the relationship between parental supervision and drug experimentation?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Parental_Supervision',y='Drug_Experimentation',data=data)
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='Parental_Supervision',y='Drug_Experimentation',data=data)
plt.show()

# %% [markdown]
# # 3.11 Substance Education: How does receiving substance education affect smoking prevalence?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Substance_Education',y='Smoking_Prevalence',data=data)
plt.show()

# %% [markdown]
# # 3.12 Community Support: Is there a correlation between community support scores and smoking prevalence?

# %%
data.columns
# Out:
# Index(['Year', 'Age_Group', 'Gender', 'Smoking_Prevalence',
#        'Drug_Experimentation', 'Socioeconomic_Status', 'Peer_Influence',
#        'School_Programs', 'Family_Background', 'Mental_Health',
#        'Access_to_Counseling', 'Parental_Supervision', 'Substance_Education',
#        'Community_Support', 'Media_Influence'],
#       dtype='object')

# %%
corr=data['Community_Support'].corr(data['Smoking_Prevalence'])


plt.figure(figsize=(10,6))
sns.scatterplot(x='Community_Support',y='Smoking_Prevalence',data=data)
plt.title(f'correlation between community support scores and smoking prevalence  {corr}')
plt.show()
